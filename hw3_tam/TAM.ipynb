# %%
# !git clone https://github.com/xmed-lab/TAM.git
# Out:
# fatal: destination path 'TAM' already exists and is not an empty directory.

# %%
# %cd TAM
# Out:
# /content/TAM

# %%
# !pip install -r requirements.txt

# %%
# !pip install opencv-python pymupdf accelerate qwen-vl-utils
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.4/35.4 MB 21.8 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# demo.py  eval.py  imgs	qwen_utils.py  README.md  requirements.txt  tam.py

# %%
# !pip uninstall -y fitz
# !pip uninstall -y pymupdf
# Out:
# Found existing installation: fitz 0.0.1.dev2
# Uninstalling fitz-0.0.1.dev2:
#   Successfully uninstalled fitz-0.0.1.dev2
# Found existing installation: PyMuPDF 1.27.2.3
# Uninstalling PyMuPDF-1.27.2.3:
#   Successfully uninstalled PyMuPDF-1.27.2.3

# %%
# !pip install pymupdf==1.24.14
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 21.2 MB/s eta 0:00:00
# ...

# %%
from PIL import Image

img = Image.open("/content/1.jpeg")
img = img.resize((336,336))
img.save("/content/cat.jpg")

# %%
# !python demo.py
# Out:
# 2026-06-18 23:24:38.255085: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# config.json: 1.20kB [00:00, 6.46MB/s]
# model.safetensors.index.json: 56.4kB [00:00, 136MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/3.99G [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:   0% 0.00/429M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   1% 25.1M/3.99G [00:02<06:01, 11.0MB/s]
# model-00001-of-00002.safetensors:   2% 67.1M/3.99G [00:02<02:01, 32.3MB/s]
# model-00001-of-00002.safetensors:   3% 134M/3.99G [00:03<01:13, 52.4MB/s]
# model-00001-of-00002.safetensors:   5% 201M/3.99G [00:08<03:03, 20.6MB/s]
#
# model-00002-of-00002.safetensors:  62% 268M/429M [00:10<00:06, 25.5MB/s]
#
# ...

# %%
# !zip -r tam_results.zip /content/tam_results
# Out:
#   adding: content/tam_results/ (stored 0%)
#   adding: content/tam_results/12.jpg (deflated 0%)
#   adding: content/tam_results/6.jpg (deflated 0%)
#   adding: content/tam_results/2.jpg (deflated 0%)
#   adding: content/tam_results/0.jpg (deflated 0%)
#   adding: content/tam_results/12.tex (deflated 70%)
#   adding: content/tam_results/7.jpg (deflated 0%)
#   adding: content/tam_results/9.jpg (deflated 0%)
#   adding: content/tam_results/14.tex (deflated 69%)
#   adding: content/tam_results/4.tex (deflated 72%)
#   adding: content/tam_results/14.jpg (deflated 0%)
#   adding: content/tam_results/9.tex (deflated 72%)
#   adding: content/tam_results/0.tex (deflated 73%)
#   adding: content/tam_results/5.tex (deflated 72%)
#   adding: content/tam_results/6.tex (deflated 72%)
#   adding: content/tam_results/1.tex (deflated 74%)
#   adding: content/tam_results/11.tex (deflated 71%)
#   adding: content/tam_results/1.jpg (deflated 0%)
#   adding: content/tam_results/13.jpg (deflated 0%)
# ...

# %%
from google.colab import files
files.download("tam_results.zip")
